# %% [markdown]
# # Wind Rose
#
# > The traditional wind rose plot plots wind speed and wind direction. The pollution rose has the same structure but replaces wind speed with pollutants.

# %% [markdown]
# Standard libraries to be imported for usage

# %%
import pandas as pd
import matplotlib.pyplot as plt

from vayu import windRose

# %% [markdown]
# Reading the data and using the function from the library.

# %%
df = pd.read_csv("../data/mydata.csv")
legend = windRose(df, 'pm25')
