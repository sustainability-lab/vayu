# %% [markdown]
# # Time Plot
#
# > The timePlot function plots time series for several pollutants.

# %% [markdown]
# Standard libraries to be imported for usage

# %%
import pandas as pd
import matplotlib.pyplot as plt

from vayu import timePlot

# %% [markdown]
# Reading the data and using the function from the library.

# %%
mydata = pd.read_csv('../data/mydata.csv')
axs = timePlot(mydata,'2003', 8)
